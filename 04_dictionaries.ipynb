# %% [markdown]
# <a href="https://colab.research.google.com/github/Faraz-Pasha1/Assignment_4_Python/blob/main/04_dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("00_count_nums")

def count_numbers():
    count_dict = {}

    while True:
        user_input = input("Enter a number (or 'exit' to quit): ")
        if user_input.lower() == "exit":
            break
        if user_input.isdigit():
            num = int(user_input)
            count_dict[num] = count_dict.get(num, 0) + 1
        else:
            print("Invalid input, please enter a valid number or 'exit'.")

    return count_dict

def display_counts(count_dict):
    print("\nNumber Count:")
    for key, value in count_dict.items():
        print(f"{key} appears {value} time(s)")

if __name__ == "__main__":
    counts = count_numbers()
    display_counts(counts)
# Out:
# 00_count_nums
# Enter a number (or 'exit' to quit): 5
# Enter a number (or 'exit' to quit): 4
# Enter a number (or 'exit' to quit): 6
# Enter a number (or 'exit' to quit): 7
# Enter a number (or 'exit' to quit): 8
# Enter a number (or 'exit' to quit): 4
# Enter a number (or 'exit' to quit): exit
#
# Number Count:
# 5 appears 1 time(s)
# 4 appears 2 time(s)
# 6 appears 1 time(s)
# 7 appears 1 time(s)
# 8 appears 1 time(s)

# %%
print("01_phonebook")

def add_contact(phonebook):
  name = input("enter contact name: ")
  number = input("enter contact number: ")

  if name in phonebook:
    print(f"{name} already exist i the phonebook.")
  else:
    phonebook[name] = number
    print(f"{name} added to the phonebook.")

def search_contact(phonebook):
  name = input("enter contact name to search: ")

  if name in phonebook:
    print(f"{name}: {phonebook[name]}")
  else:
    print(f"{name} not found in the phonebook.")

def delete_contact(phonebook):
  name = input("Enter contact name to delete: ")
  if name in phonebook:
    del phonebook[name]
    print(f"{name} deleted successfully")
  else:
    print(f"{name} not found in phonebook.")


def display_contact(phonebook):
  if phonebook:
    print("\n Phonebook contact list")
    for name,number in phonebook.items():
      print(f"{name}: {number}")
    else:
      print("Phonebook is empty ")

if __name__ == "__main__":
  phonebook = {}

  while True:
    print("\n Phonebook Menu")
    print("1. Add Contact")
    print("2. Search Contact")
    print("3. Delete Contact")
    print("4. Display Contact")
    print("5. Exit")

    choice = input("Enter your choice (1-5): ")

    if choice == "1":
      add_contact(phonebook)
    elif choice == "2":
      search_contact(phonebook)
    elif choice == "3":
      delete_contact(phonebook)
    elif choice == "4":
      display_contact(phonebook)
    elif choice == "5":
      print("Exiting PHonebook")
      break
    else:
      print("invalid choice")
# Out:
# 01_phonebook
#
#  Phonebook Menu
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contact
# 5. Exit
# Enter your choice (1-5): 1
# enter contact name: faraz
# enter contact number: 03322457913
# faraz added to the phonebook.
#
#  Phonebook Menu
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contact
# 5. Exit
# Enter your choice (1-5): 5
# Exiting PHonebook

# %%
print("02_pop_up_shop")

def calculate_total_cost():
    fruits_price = {
        "apple": 5.0,
        "mango": 15.0,
        "kiwi": 8.0,
        "pear": 12.0,
        "banana": 6.0,
        "orange": 10.0
    }

    total_cost = 0

    for fruit, price in fruits_price.items():
        while True:
            try:
                quantity = int(input(f"How many {fruit}s do you want? "))
                if quantity < 0:
                    print("Please enter a non-negative number.")
                    continue
                total_cost += price * quantity
                break
            except ValueError:
                print("Invalid input. Please enter a whole number.")

    print(f"\nTotal cost of your fruits is: ${total_cost:.2f}")

if __name__ == '__main__':
    calculate_total_cost()
# Out:
# 02_pop_up_shop
# 02_pop_up_shop
# How many apples do you want? 1
# How many mangos do you want? 2
# How many kiwis do you want? 3
# How many pears do you want? 4
# How many bananas do you want? 5
# How many oranges do you want? 6
#
# Total cost of your fruits is: $197.00

# %%
import hashlib

print("03_powerful_passwords")

def hash_password(password):
  return hashlib.sha256(password.encode()).hexdigest()

stored_logins = {
    "user@example.com" : hash_password("password123"),
    "user@example.com" : hash_password("password456"),

}
def login(email,password):
  if email in stored_logins:
    return stored_logins[email] == hash_password(password)
  return False

if __name__ == "__main__":
    email = input("Enter your Email: ")
    password = input("enter your password: ")

    if login(email,password):
      print("login succesfull")
    else:
      print("invalid email and password")
# Out:
# 03_powerful_passwords
# Enter your Email:
# enter your password:
# invalid email and password
