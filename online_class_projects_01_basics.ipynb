# %% [markdown]
# <a href="https://colab.research.google.com/github/Faraz-Pasha1/Assignment_4_Python/blob/main/online_class_projects_01_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("00_joke_bot")

prompt: str = "what do u want"
joke: str = "I told my wife she was drawing her eyebrows too high... She looked surprised. 😳😂"
sorry: str = "sorry I only tell jokes"

def main():
    user_input = input(prompt).strip().lower()

    if "joke" in user_input:
        print(joke)
    else:
        print(sorry)

if __name__ == "__main__":
    main()
# Out:
# 00_joke_bot
# what do u wantjoke
# I told my wife she was drawing her eyebrows too high... She looked surprised. 😳😂

# %%
print("01_double_it")

def main():
 user_value = int(input("enter a number: "))
 while user_value < 100:
    user_value = user_value * 2
    print(user_value)

if __name__ == "__main__":
  main()

# %%
print("02_liftoff")

def main():
  for i in range(10,0,-1):
    print(i,end = " ")
  print("Liftloff")

if __name__ == "__main__":
  main()

# %%
import random
print("03_guess_my_number")

def main():
  secret_number = random.randint(1,100)
  print("I am thinking a number between 1 to 100..")

  guess = int(input("Enter a guess: "))

  while guess != secret_number:
    if guess < secret_number:
      print("Your huess is too low")
    else:
      print("Your guess is too high")
    guess = int(input("enter a guess: "))

  print(f"Congratulation! the number was {secret_number}")

if __name__ == "__main__":
  main()

# %%
import random
print("05_random_numbers")

def main():
  for i in range(10):
    num:list[int] = random.randint(1,100)
    print(num)

if __name__ == '__main__':
    main()
